# %%
# Aktuell bestes Modell aufbauen 
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import kerastuner as kt
import shutil
import os
import json
from keras import layers
import gc
from sklearn.metrics import mean_absolute_error


def bestes_model(X_train_scaled, X_val_scaled, X_test_scaled, Y_train_scaled, Y_val_scaled, Y_test_scaled, Y_train, Y_val, Y_test, scalers_features, scaler_labels):
      
    Y_train = np.squeeze(Y_train)
    Y_test = np.squeeze(Y_test)
    Y_val =np.squeeze(Y_val)
    Y_train_scaled = np.squeeze(Y_train_scaled)
    Y_val_scaled = np.squeeze(Y_val_scaled)
    
    # TensorFlow-Sitzung zurücksetzen
    tf.keras.backend.clear_session()
    gc.collect()

# LSTM Modell definieren
    input_layer = layers.Input(shape=(10,11))

    # RNN Layers
    rnn_1 = layers.SimpleRNN(64, activation='sigmoid', kernel_regularizer=keras.regularizers.l2(0.001))(input_layer)



    # print(flatten)
    # print(type(flatten))
    # print(flatten.shape)

    # Fully Connected Layers
    dense_layer = layers.Dense(224, activation='relu', kernel_regularizer=keras.regularizers.l2(0.009))(rnn_1)
    dense_layer_1 = layers.Dense(224, activation='relu', kernel_regularizer=keras.regularizers.l2(0.0))(dense_layer)
    dense_layer_2 = layers.Dense(96, activation='tanh', kernel_regularizer=keras.regularizers.l2(0.007))(dense_layer_1)
    dense_layer_3 = layers.Dense(96, activation='tanh', kernel_regularizer=keras.regularizers.l2(0.004))(dense_layer_2)
    dense_layer_4 = layers.Dense(288, activation='relu', kernel_regularizer=keras.regularizers.l2(0.003))(dense_layer_3)
    
    # Output Layers definieren
    X_output = layers.Dense(1, activation='linear', name='Verstellweg_X')(dense_layer_4)
    Y_output = layers.Dense(1, activation='linear', name='Verstellweg_Y')(dense_layer_4)
    Phi_output = layers.Dense(1, activation='linear', name='Verstellweg_Phi')(dense_layer_4)

    # Liste erstellen für alle Outputs
    outputs = [X_output, Y_output, Phi_output]

    # Modell definieren 
    model = keras.Model(inputs=input_layer, outputs=outputs)

    
        # Kompilieren des Modells
    model.compile(optimizer=keras.optimizers.Adam(0.0004426556642885296), 
                loss=['mean_absolute_error', 'mean_absolute_error', 'mean_absolute_error'], 
                metrics={'Verstellweg_X': 'mae', 'Verstellweg_Y': 'mae', 'Verstellweg_Phi': 'mae'})

    # Modell zusammenfassen
    #model.summary()

    # Define early stopping to prevent overfitting
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

    CNN = model.fit(X_train_scaled, [Y_train[:,0], Y_train[:,1], Y_train[:,2]],
                            epochs=20,
                            validation_data=(X_val_scaled, [Y_val[:, 0], Y_val[:, 1], Y_val[:, 2]]),
                            callbacks=[early_stopping])
    
    # Vorhersagen für den Testdatensatz erstellen
    predictions = model.predict(X_test_scaled)
    X_p, Y_p, Phi_p = predictions
    
    # print(X_p.shape)
    # print(X_p[:,0].shape)
    # print(Y_test[:,0].shape)
     # Error für jedes Label berechnen
    Fehler_X = Y_test[:,0]-X_p[:,0]
    Fehler_Y = Y_test[:,1]-Y_p[:,0]
    Fehler_Phi = Y_test[:,2]-Phi_p[:,0]
    
    # print(Fehler_X)
    # print(Fehler_X.shape)
    
    # Fehler in einen DataFrame konvertieren
    df_Fehler = pd.DataFrame({
        'Label_X': Y_test[:,0],
        'Label_Y': Y_test[:,1],
        'Label_Phi': Y_test[:,2],
        'Fehler_X': Fehler_X,
        'Fehler_Y': Fehler_Y,
        'Fehler_Phi': Fehler_Phi})
    
    mae_X = mean_absolute_error(Y_test[:, 0], X_p)
    mae_Y = mean_absolute_error(Y_test[:, 1], Y_p)
    mae_Phi = mean_absolute_error(Y_test[:, 2], Phi_p)

    # X und Y kombinieren da diese zusammen sakliert werden
    # XY_p = np.column_stack((X_p, Y_p))

    # Rückskalierung der Vorhersagen
    # XY_pred = scaler_Y_mm.inverse_transform(XY_p)
    # X_pred, Y_pred = XY_pred[:, 0], XY_pred[:, 1]
    # Phi_pred = scaler_Y_phi.inverse_transform(Phi_p.reshape(-1, 1)).flatten()
    
    # MAE für den Testdatensatz berechnen
    # mae_X = mean_absolute_error(Y_test[:,0], X_p)
    # mae_Y = mean_absolute_error(Y_test[:,1], Y_p)
    # mae_Phi = mean_absolute_error(Y_test[:,2], Phi_p)

    print(f"Mean Absolute Error for Verstellweg_X: {mae_X}")
    print(f"Mean Absolute Error for Verstellweg_Y: {mae_Y}")
    print(f"Mean Absolute Error for Verstellweg_Phi: {mae_Phi}")
    
    return mae_X, mae_Y, mae_Phi, df_Fehler
# Out:
# C:\Users\corvi\AppData\Local\Temp\ipykernel_36652\1010669504.py:9: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %%
import random 
from Splitting_Scaling_Function_SkalierungY import Split_Scaling
from Load_Data_for_Modelling_Function import Data_for_Model
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from Fensterung_Scaling_CNN_ValData import Fensterung_Scale
from sklearn.metrics import mean_absolute_error
import pandas as pd


random.seed(2)
# Generieren einer Liste von 10 eindeutigen zufälligen Ganzzahlen zwischen 0 und 100
Random_numbers = random.sample(range(101), 10)
print(Random_numbers)

# Random_numbers = Random_numbers[7:10]
# print(Random_numbers)


MAE_StandardSplit_df = pd.DataFrame(columns=['CV', 'Datentyp','Error', 'X', 'y', 'phi'])
MAE_BlechSplit_df = pd.DataFrame(columns=['CV', 'Datentyp','Error', 'X', 'y', 'phi'])


data = Data_for_Model(0,1800)

Liste_Fehler_Blechsplit = []
Liste_Fehler_Standardsplit= []

Liste_MAEs_Blechsplit =[]
Liste_MAEs_Standardsplit = []

MAE_StandardSplit_leer = pd.DataFrame(columns=['CV', 'Datentyp','Error', 'X', 'y', 'phi'])
MAE_BlechSplit_leer = pd.DataFrame(columns=['CV', 'Datentyp','Error', 'X', 'y', 'phi'])

for n in Random_numbers:
    
    X_train, X_val, X_test, Y_train_scaled, Y_val_scaled, Y_test_scaled, Y_train, Y_val, Y_test, scalers_features, scaler_labels, Angepasste_Blechnummern_test = Fensterung_Scale(data, Validation_data=1, random=n, Train_Test_Split =1, size=0.2)
    mae_X, mae_Y, mae_phi, df_Fehler = bestes_model(X_train, X_val, X_test, Y_train_scaled, Y_val_scaled, Y_test_scaled, Y_train, Y_val, Y_test, scalers_features, scaler_labels)
    
    MAE_StandardSplit_df = pd.DataFrame([{'CV':n, 'Datentyp': 'Standardsplit', 'Error' : 'MAE', 'X': mae_X, 'y': mae_Y, 'phi': mae_phi}])
    Liste_MAEs_Standardsplit.append(MAE_StandardSplit_df)
    
    df_Fehler.insert(loc=0, column='SplitMethode', value='Standardsplit')
    df_Fehler.insert(loc=1, column='CV', value=n)
    Liste_Fehler_Standardsplit.append(df_Fehler)
    
MAE_Standardsplit = pd.concat(Liste_MAEs_Standardsplit, ignore_index=True)
Fehler_Standardsplit_df = pd.concat(Liste_Fehler_Standardsplit, ignore_index=True)

# for n in Random_numbers:
    
#     X_train, X_val, X_test, Y_train_scaled, Y_val_scaled, Y_test_scaled, Y_train, Y_val, Y_test, scalers_features, scaler_labels, Angepasste_Blechnummern_test   = Fensterung_Scale(data, Validation_data=1, random=n, Train_Test_Split =2, size=0.2)
#     mae_X, mae_Y, mae_phi, df_Fehler = bestes_model(X_train, X_val, X_test, Y_train_scaled, Y_val_scaled, Y_test_scaled, Y_train, Y_val, Y_test, scalers_features, scaler_labels)
    
#     MAE_BlechSplit_df = pd.DataFrame([{'CV':n, 'Datentyp': 'Blechsplit', 'Error' : 'MAE', 'X': mae_X, 'y': mae_Y, 'phi': mae_phi}])
#     Liste_MAEs_Blechsplit.append(MAE_BlechSplit_df)
    
#     df_Fehler.insert(loc=0, column='SplitMethode', value='Blechsplit')
#     df_Fehler.insert(loc=1, column='CV', value=n)
#     Liste_Fehler_Blechsplit.append(df_Fehler)
    
# MAE_Blechsplit = pd.concat(Liste_MAEs_Blechsplit, ignore_index=True)
# Fehler_Blechsplit_df = pd.concat(Liste_Fehler_Blechsplit, ignore_index=True)
    
    
# Ausgabe der DataFrames
print("MAE Standard Split:")
print(MAE_StandardSplit_df)
print("\nMAE Blech Split:")
print(MAE_Blechsplit)
# Out:
# [7, 11, 10, 46, 21, 94, 85, 39, 32, 77]
# Anzahl der Zeilen im finalen DataFrame: 255600
# None
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - Verstellweg_Phi_mae: 1.1930 - Verstellweg_X_mae: 0.1304 - Verstellweg_Y_mae: 0.8543 - loss: 2.9795 - val_Verstellweg_Phi_mae: 0.6035 - val_Verstellweg_X_mae: 0.0375 - val_Verstellweg_Y_mae: 0.4266 - val_loss: 1.4113
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step - Verstellweg_Phi_mae: 0.5799 - Verstellweg_X_mae: 0.0293 - Verstellweg_Y_mae: 0.3867 - loss: 1.3152 - val_Verstellweg_Phi_mae: 0.4155 - val_Verstellweg_X_mae: 0.0166 - val_Verstellweg_Y_mae: 0.2757 - val_loss: 0.9969
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 27s 4ms/step
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - Verstellweg_Phi_mae: 0.0966 - Verstellweg_X_mae: 0.0115 - Verstellweg_Y_mae: 0.1084 - loss: 0.3745 - val_Verstellweg_Phi_mae: 0.0905 - val_Verstellweg_X_mae: 0.0071 - val_Verstellweg_Y_mae: 0.0897 - val_loss: 0.3417
# Epoch 14/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.0896 - Verstellweg_X_mae: 0.0113 - Verstellweg_Y_mae: 0.1046 - loss: 0.3584 - val_Verstellweg_Phi_mae: 0.0675 - val_Verstellweg_X_mae: 0.0091 - val_Verstellweg_Y_mae: 0.1067 - val_loss: 0.3324
# Epoch 15/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.0827 - Verstellweg_X_mae: 0.0110 - Verstellweg_Y_mae: 0.1009 - loss: 0.3422 - val_Verstellweg_Phi_mae: 0.0757 - val_Verstellweg_X_mae: 0.0086 - val_Verstellweg_Y_mae: 0.0958 - val_loss: 0.3243
# Epoch 16/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 37s 6ms/step - Verstellweg_Phi_mae: 0.0824 - Verstellweg_X_mae: 0.0108 - Verstellweg_Y_mae: 0.0976 - loss: 0.3338 - val_Verstellweg_Phi_mae: 0.0704 - val_Verstellweg_X_mae: 0.0122 - val_Verstellweg_Y_mae: 0.1072 - val_loss: 0.3299
# Epoch 17/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 43s 7ms/step - Verstellweg_Phi_mae: 0.0776 - Verstellweg_X_mae: 0.0111 - Verstellweg_Y_mae: 0.0956 - loss: 0.3233 - val_Verstellweg_Phi_mae: 0.0780 - val_Verstellweg_X_mae: 0.0131 - val_Verstellweg_Y_mae: 0.0859 - val_loss: 0.3133
# Epoch 18/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 37s 6ms/step - Verstellweg_Phi_mae: 0.0735 - Verstellweg_X_mae: 0.0107 - Verstellweg_Y_mae: 0.0948 - loss: 0.3144 - val_Verstellweg_Phi_mae: 0.0666 - val_Verstellweg_X_mae: 0.0213 - val_Verstellweg_Y_mae: 0.1063 - val_loss: 0.3261
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.0721 - Verstellweg_X_mae: 0.0108 - Verstellweg_Y_mae: 0.0882 - loss: 0.3028 - val_Verstellweg_Phi_mae: 0.0876 - val_Verstellweg_X_mae: 0.0078 - val_Verstellweg_Y_mae: 0.0968 - val_loss: 0.3213
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 34s 5ms/step - Verstellweg_Phi_mae: 0.0689 - Verstellweg_X_mae: 0.0110 - Verstellweg_Y_mae: 0.0871 - loss: 0.2954 - val_Verstellweg_Phi_mae: 0.0527 - val_Verstellweg_X_mae: 0.0085 - val_Verstellweg_Y_mae: 0.0790 - val_loss: 0.2659
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.008454227289194455
# Mean Absolute Error for Verstellweg_Y: 0.0778765172704712
# Mean Absolute Error for Verstellweg_Phi: 0.05352158045674455
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.0766 - Verstellweg_X_mae: 0.0105 - Verstellweg_Y_mae: 0.0952 - loss: 0.3153 - val_Verstellweg_Phi_mae: 0.0780 - val_Verstellweg_X_mae: 0.0124 - val_Verstellweg_Y_mae: 0.0981 - val_loss: 0.3188
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.012530118625632905
# Mean Absolute Error for Verstellweg_Y: 0.09762218681659682
# Mean Absolute Error for Verstellweg_Phi: 0.07794830510277735
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 4ms/step - Verstellweg_Phi_mae: 1.1539 - Verstellweg_X_mae: 0.1307 - Verstellweg_Y_mae: 0.8648 - loss: 2.9419 - val_Verstellweg_Phi_mae: 0.6361 - val_Verstellweg_X_mae: 0.0213 - val_Verstellweg_Y_mae: 0.4707 - val_loss: 1.4720
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.5695 - Verstellweg_X_mae: 0.0241 - Verstellweg_Y_mae: 0.3696 - loss: 1.2839 - val_Verstellweg_Phi_mae: 0.4180 - val_Verstellweg_X_mae: 0.0149 - val_Verstellweg_Y_mae: 0.2787 - val_loss: 0.9975
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.3746 - Verstellweg_X_mae: 0.0137 - Verstellweg_Y_mae: 0.2399 - loss: 0.9054 - val_Verstellweg_Phi_mae: 0.2843 - val_Verstellweg_X_mae: 0.0132 - val_Verstellweg_Y_mae: 0.2122 - val_loss: 0.7578
# Epoch 4/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.2729 - Verstellweg_X_mae: 0.0122 - Verstellweg_Y_mae: 0.1944 - loss: 0.7223 - val_Verstellweg_Phi_mae: 0.2359 - val_Verstellweg_X_mae: 0.0128 - val_Verstellweg_Y_mae: 0.1566 - val_loss: 0.6314
# Epoch 5/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.2257 - Verstellweg_X_mae: 0.0115 - Verstellweg_Y_mae: 0.1715 - loss: 0.6298 - val_Verstellweg_Phi_mae: 0.1939 - val_Verstellweg_X_mae: 0.0092 - val_Verstellweg_Y_mae: 0.1527 - val_loss: 0.5659
# Epoch 6/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.1963 - Verstellweg_X_mae: 0.0114 - Verstellweg_Y_mae: 0.1569 - loss: 0.5704 - val_Verstellweg_Phi_mae: 0.1713 - val_Verstellweg_X_mae: 0.0135 - val_Verstellweg_Y_mae: 0.1324 - val_loss: 0.5151
# Epoch 7/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - Verstellweg_Phi_mae: 0.1734 - Verstellweg_X_mae: 0.0115 - Verstellweg_Y_mae: 0.1453 - loss: 0.5263 - val_Verstellweg_Phi_mae: 0.1415 - val_Verstellweg_X_mae: 0.0069 - val_Verstellweg_Y_mae: 0.1231 - val_loss: 0.4651
# Epoch 8/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - Verstellweg_Phi_mae: 0.0794 - Verstellweg_X_mae: 0.0103 - Verstellweg_Y_mae: 0.0954 - loss: 0.3207 - val_Verstellweg_Phi_mae: 0.0842 - val_Verstellweg_X_mae: 0.0068 - val_Verstellweg_Y_mae: 0.0776 - val_loss: 0.3023
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.0767 - Verstellweg_X_mae: 0.0102 - Verstellweg_Y_mae: 0.0926 - loss: 0.3121 - val_Verstellweg_Phi_mae: 0.0629 - val_Verstellweg_X_mae: 0.0107 - val_Verstellweg_Y_mae: 0.0766 - val_loss: 0.2801
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0748 - Verstellweg_X_mae: 0.0103 - Verstellweg_Y_mae: 0.0904 - loss: 0.3049 - val_Verstellweg_Phi_mae: 0.0608 - val_Verstellweg_X_mae: 0.0075 - val_Verstellweg_Y_mae: 0.0820 - val_loss: 0.2778
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.007647033612927466
# Mean Absolute Error for Verstellweg_Y: 0.0825730176770485
# Mean Absolute Error for Verstellweg_Phi: 0.062252692384289564
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 1.1844 - Verstellweg_X_mae: 0.1125 - Verstellweg_Y_mae: 0.8603 - loss: 2.9529 - val_Verstellweg_Phi_mae: 0.6577 - val_Verstellweg_X_mae: 0.0308 - val_Verstellweg_Y_mae: 0.4558 - val_loss: 1.4910
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.5911 - Verstellweg_X_mae: 0.0249 - Verstellweg_Y_mae: 0.4329 - loss: 1.3680 - val_Verstellweg_Phi_mae: 0.4596 - val_Verstellweg_X_mae: 0.0190 - val_Verstellweg_Y_mae: 0.2948 - val_loss: 1.0633
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.3970 - Verstellweg_X_mae: 0.0148 - Verstellweg_Y_mae: 0.2780 - loss: 0.9738 - val_Verstellweg_Phi_mae: 0.3436 - val_Verstellweg_X_mae: 0.0076 - val_Verstellweg_Y_mae: 0.2111 - val_loss: 0.8184
# Epoch 4/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.3060 - Verstellweg_X_mae: 0.0130 - Verstellweg_Y_mae: 0.2158 - loss: 0.7837 - val_Verstellweg_Phi_mae: 0.2531 - val_Verstellweg_X_mae: 0.0114 - val_Verstellweg_Y_mae: 0.1807 - val_loss: 0.6778
# Epoch 5/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.2549 - Verstellweg_X_mae: 0.0126 - Verstellweg_Y_mae: 0.1839 - loss: 0.6786 - val_Verstellweg_Phi_mae: 0.2210 - val_Verstellweg_X_mae: 0.0252 - val_Verstellweg_Y_mae: 0.1574 - val_loss: 0.6175
# Epoch 6/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0887 - Verstellweg_X_mae: 0.0112 - Verstellweg_Y_mae: 0.0966 - loss: 0.3382 - val_Verstellweg_Phi_mae: 0.0934 - val_Verstellweg_X_mae: 0.0133 - val_Verstellweg_Y_mae: 0.0983 - val_loss: 0.3440
# Epoch 18/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0853 - Verstellweg_X_mae: 0.0113 - Verstellweg_Y_mae: 0.0947 - loss: 0.3295 - val_Verstellweg_Phi_mae: 0.0755 - val_Verstellweg_X_mae: 0.0063 - val_Verstellweg_Y_mae: 0.0780 - val_loss: 0.2955
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0821 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.0930 - loss: 0.3204 - val_Verstellweg_Phi_mae: 0.1069 - val_Verstellweg_X_mae: 0.0103 - val_Verstellweg_Y_mae: 0.1092 - val_loss: 0.3590
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0784 - Verstellweg_X_mae: 0.0109 - Verstellweg_Y_mae: 0.0921 - loss: 0.3128 - val_Verstellweg_Phi_mae: 0.0692 - val_Verstellweg_X_mae: 0.0092 - val_Verstellweg_Y_mae: 0.0954 - val_loss: 0.3032
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.009242992382020272
# Mean Absolute Error for Verstellweg_Y: 0.09478952791286524
# Mean Absolute Error for Verstellweg_Phi: 0.06804004671519336
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 1.2294 - Verstellweg_X_mae: 0.1581 - Verstellweg_Y_mae: 0.8273 - loss: 3.0036 - val_Verstellweg_Phi_mae: 0.7546 - val_Verstellweg_X_mae: 0.0394 - val_Verstellweg_Y_mae: 0.3745 - val_loss: 1.5265
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.5737 - Verstellweg_X_mae: 0.0286 - Verstellweg_Y_mae: 0.3581 - loss: 1.2952 - val_Verstellweg_Phi_mae: 0.4659 - val_Verstellweg_X_mae: 0.0187 - val_Verstellweg_Y_mae: 0.2601 - val_loss: 1.0429
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.3841 - Verstellweg_X_mae: 0.0172 - Verstellweg_Y_mae: 0.2535 - loss: 0.9443 - val_Verstellweg_Phi_mae: 0.3149 - val_Verstellweg_X_mae: 0.0087 - val_Verstellweg_Y_mae: 0.1986 - val_loss: 0.7873
# Epoch 4/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.2869 - Verstellweg_X_mae: 0.0131 - Verstellweg_Y_mae: 0.2036 - loss: 0.7613 - val_Verstellweg_Phi_mae: 0.2378 - val_Verstellweg_X_mae: 0.0109 - val_Verstellweg_Y_mae: 0.1557 - val_loss: 0.6438
# Epoch 5/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.2361 - Verstellweg_X_mae: 0.0122 - Verstellweg_Y_mae: 0.1799 - loss: 0.6624 - val_Verstellweg_Phi_mae: 0.2065 - val_Verstellweg_X_mae: 0.0102 - val_Verstellweg_Y_mae: 0.1914 - val_loss: 0.6304
# Epoch 6/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.0853 - Verstellweg_X_mae: 0.0105 - Verstellweg_Y_mae: 0.0993 - loss: 0.3445 - val_Verstellweg_Phi_mae: 0.0959 - val_Verstellweg_X_mae: 0.0126 - val_Verstellweg_Y_mae: 0.0837 - val_loss: 0.3380
# Epoch 17/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.0798 - Verstellweg_X_mae: 0.0102 - Verstellweg_Y_mae: 0.0944 - loss: 0.3290 - val_Verstellweg_Phi_mae: 0.0793 - val_Verstellweg_X_mae: 0.0069 - val_Verstellweg_Y_mae: 0.1066 - val_loss: 0.3345
# Epoch 18/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.0762 - Verstellweg_X_mae: 0.0099 - Verstellweg_Y_mae: 0.0939 - loss: 0.3204 - val_Verstellweg_Phi_mae: 0.0718 - val_Verstellweg_X_mae: 0.0151 - val_Verstellweg_Y_mae: 0.1111 - val_loss: 0.3357
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.015054930569696373
# Mean Absolute Error for Verstellweg_Y: 0.11081738561422315
# Mean Absolute Error for Verstellweg_Phi: 0.07111330794320211
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 1.2034 - Verstellweg_X_mae: 0.1136 - Verstellweg_Y_mae: 0.8391 - loss: 3.0070 - val_Verstellweg_Phi_mae: 0.6126 - val_Verstellweg_X_mae: 0.0234 - val_Verstellweg_Y_mae: 0.3988 - val_loss: 1.4059
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.5678 - Verstellweg_X_mae: 0.0259 - Verstellweg_Y_mae: 0.3736 - loss: 1.3097 - val_Verstellweg_Phi_mae: 0.4054 - val_Verstellweg_X_mae: 0.0173 - val_Verstellweg_Y_mae: 0.2570 - val_loss: 0.9835
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.3727 - Verstellweg_X_mae: 0.0151 - Verstellweg_Y_mae: 0.2485 - loss: 0.9301 - val_Verstellweg_Phi_mae: 0.2745 - val_Verstellweg_X_mae: 0.0193 - val_Verstellweg_Y_mae: 0.2271 - val_loss: 0.7866
# Epoch 4/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.2765 - Verstellweg_X_mae: 0.0122 - Verstellweg_Y_mae: 0.2036 - loss: 0.7510 - val_Verstellweg_Phi_mae: 0.2259 - val_Verstellweg_X_mae: 0.0122 - val_Verstellweg_Y_mae: 0.1825 - val_loss: 0.6613
# Epoch 5/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.2301 - Verstellweg_X_mae: 0.0120 - Verstellweg_Y_mae: 0.1793 - loss: 0.6568 - val_Verstellweg_Phi_mae: 0.2139 - val_Verstellweg_X_mae: 0.0111 - val_Verstellweg_Y_mae: 0.1956 - val_loss: 0.6444
# Epoch 6/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - Verstellweg_Phi_mae: 0.0859 - Verstellweg_X_mae: 0.0112 - Verstellweg_Y_mae: 0.1035 - loss: 0.3542 - val_Verstellweg_Phi_mae: 0.1030 - val_Verstellweg_X_mae: 0.0103 - val_Verstellweg_Y_mae: 0.0891 - val_loss: 0.3528
# Epoch 16/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 34s 5ms/step - Verstellweg_Phi_mae: 0.0832 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.0998 - loss: 0.3424 - val_Verstellweg_Phi_mae: 0.0808 - val_Verstellweg_X_mae: 0.0083 - val_Verstellweg_Y_mae: 0.0857 - val_loss: 0.3203
# Epoch 17/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.0783 - Verstellweg_X_mae: 0.0104 - Verstellweg_Y_mae: 0.0966 - loss: 0.3297 - val_Verstellweg_Phi_mae: 0.0968 - val_Verstellweg_X_mae: 0.0107 - val_Verstellweg_Y_mae: 0.0945 - val_loss: 0.3428
# Epoch 18/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.0772 - Verstellweg_X_mae: 0.0105 - Verstellweg_Y_mae: 0.0920 - loss: 0.3200 - val_Verstellweg_Phi_mae: 0.0700 - val_Verstellweg_X_mae: 0.0126 - val_Verstellweg_Y_mae: 0.0743 - val_loss: 0.2938
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0741 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.0893 - loss: 0.3105 - val_Verstellweg_Phi_mae: 0.0706 - val_Verstellweg_X_mae: 0.0099 - val_Verstellweg_Y_mae: 0.0869 - val_loss: 0.3011
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0711 - Verstellweg_X_mae: 0.0101 - Verstellweg_Y_mae: 0.0878 - loss: 0.3019 - val_Verstellweg_Phi_mae: 0.0712 - val_Verstellweg_X_mae: 0.0094 - val_Verstellweg_Y_mae: 0.0942 - val_loss: 0.3051
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.009328800415501786
# Mean Absolute Error for Verstellweg_Y: 0.09204674708870927
# Mean Absolute Error for Verstellweg_Phi: 0.07197870171618963
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - Verstellweg_Phi_mae: 1.2072 - Verstellweg_X_mae: 0.1161 - Verstellweg_Y_mae: 0.8553 - loss: 2.9973 - val_Verstellweg_Phi_mae: 0.6029 - val_Verstellweg_X_mae: 0.0232 - val_Verstellweg_Y_mae: 0.3542 - val_loss: 1.3266
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step - Verstellweg_Phi_mae: 0.5858 - Verstellweg_X_mae: 0.0195 - Verstellweg_Y_mae: 0.3412 - loss: 1.2676 - val_Verstellweg_Phi_mae: 0.3883 - val_Verstellweg_X_mae: 0.0154 - val_Verstellweg_Y_mae: 0.2389 - val_loss: 0.9268
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 28s 4ms/step
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - Verstellweg_Phi_mae: 0.0980 - Verstellweg_X_mae: 0.0107 - Verstellweg_Y_mae: 0.1076 - loss: 0.3710 - val_Verstellweg_Phi_mae: 0.0764 - val_Verstellweg_X_mae: 0.0111 - val_Verstellweg_Y_mae: 0.1009 - val_loss: 0.3382
# Epoch 14/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0919 - Verstellweg_X_mae: 0.0105 - Verstellweg_Y_mae: 0.1047 - loss: 0.3563 - val_Verstellweg_Phi_mae: 0.0802 - val_Verstellweg_X_mae: 0.0113 - val_Verstellweg_Y_mae: 0.1178 - val_loss: 0.3554
# Epoch 15/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 4ms/step - Verstellweg_Phi_mae: 0.0868 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.1018 - loss: 0.3437 - val_Verstellweg_Phi_mae: 0.0845 - val_Verstellweg_X_mae: 0.0116 - val_Verstellweg_Y_mae: 0.1034 - val_loss: 0.3404
# Epoch 16/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0835 - Verstellweg_X_mae: 0.0109 - Verstellweg_Y_mae: 0.0997 - loss: 0.3347 - val_Verstellweg_Phi_mae: 0.0863 - val_Verstellweg_X_mae: 0.0076 - val_Verstellweg_Y_mae: 0.1026 - val_loss: 0.3338
# Epoch 17/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.0791 - Verstellweg_X_mae: 0.0103 - Verstellweg_Y_mae: 0.0962 - loss: 0.3222 - val_Verstellweg_Phi_mae: 0.0962 - val_Verstellweg_X_mae: 0.0100 - val_Verstellweg_Y_mae: 0.1032 - val_loss: 0.3433
# Epoch 18/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0775 - Verstellweg_X_mae: 0.0104 - Verstellweg_Y_mae: 0.0946 - loss: 0.3158 - val_Verstellweg_Phi_mae: 0.0785 - val_Verstellweg_X_mae: 0.0200 - val_Verstellweg_Y_mae: 0.0876 - val_loss: 0.3171
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0741 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.0914 - loss: 0.3064 - val_Verstellweg_Phi_mae: 0.0736 - val_Verstellweg_X_mae: 0.0096 - val_Verstellweg_Y_mae: 0.0891 - val_loss: 0.2997
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 29s 5ms/step - Verstellweg_Phi_mae: 0.0716 - Verstellweg_X_mae: 0.0103 - Verstellweg_Y_mae: 0.0899 - loss: 0.2987 - val_Verstellweg_Phi_mae: 0.0703 - val_Verstellweg_X_mae: 0.0127 - val_Verstellweg_Y_mae: 0.0832 - val_loss: 0.2911
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.012981035640748184
# Mean Absolute Error for Verstellweg_Y: 0.08440241701697239
# Mean Absolute Error for Verstellweg_Phi: 0.07054614889917767
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━
━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.007042124747405721
# Mean Absolute Error for Verstellweg_Y: 0.08641789357078765
# Mean Absolute Error for Verstellweg_Phi: 0.08133924905930641
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 35s 5ms/step - Verstellweg_Phi_mae: 1.2001 - Verstellweg_X_mae: 0.1404 - Verstellweg_Y_mae: 0.8860 - loss: 3.0134 - val_Verstellweg_Phi_mae: 0.6531 - val_Verstellweg_X_mae: 0.0232 - val_Verstellweg_Y_mae: 0.4193 - val_loss: 1.4357
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.5862 - Verstellweg_X_mae: 0.0258 - Verstellweg_Y_mae: 0.3756 - loss: 1.3056 - val_Verstellweg_Phi_mae: 0.4261 - val_Verstellweg_X_mae: 0.0220 - val_Verstellweg_Y_mae: 0.2687 - val_loss: 1.0101
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.4028 - Verstellweg_X_mae: 0.0158 - Verstellweg_Y_mae: 0.2473 - loss: 0.9501 - val_Verstellweg_Phi_mae: 0.2978 - val_Verstellweg_X_mae: 0.0113 - val_Verstellweg_Y_mae: 0.2048 - val_loss: 0.7717
# Epoch 4/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 35s 5ms/step - Verstellweg_Phi_mae: 0.3092 - Verstellweg_X_mae: 0.0125 - Verstellweg_Y_mae: 0.1996 - loss: 0.7728 - val_Verstellweg_Phi_mae: 0.2603 - val_Verstellweg_X_mae: 0.0135 - val_Verstellweg_Y_mae: 0.1888 - val_loss: 0.6980
# Epoch 5/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.2560 - Verstellweg_X_mae: 0.0121 - Verstellweg_Y_mae: 0.1776 - loss: 0.6768 - val_Verstellweg_Phi_mae: 0.2189 - val_Verstellweg_X_mae: 0.0089 - val_Verstellweg_Y_mae: 0.1507 - val_loss: 0.5986
# Epoch 6/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.2211 - Verstellweg_X_mae: 0.0116 - Verstellweg_Y_mae: 0.1592 - loss: 0.6107 - val_Verstellweg_Phi_mae: 0.1794 - val_Verstellweg_X_mae: 0.0133 - val_Verstellweg_Y_mae: 0.1547 - val_loss: 0.5615
# Epoch 7/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.1888 - Verstellweg_X_mae: 0.0115 - Verstellweg_Y_mae: 0.1481 - loss: 0.5613 - val_Verstellweg_Phi_mae: 0.2120 - val_Verstellweg_X_mae: 0.0137 - val_Verstellweg_Y_mae: 0.1292 - val_loss: 0.5644
# Epoch 8/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.1569 - Verstellweg_X_mae: 0.0112 - Verstellweg_Y_mae: 0.1353 - loss: 0.5106 - val_Verstellweg_Phi_mae: 0.1585 - val_Verstellweg_X_mae: 0.0087 - val_Verstellweg_Y_mae: 0.1263 - val_loss: 0.4923
# Epoch 9/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.0849 - Verstellweg_X_mae: 0.0109 - Verstellweg_Y_mae: 0.0936 - loss: 0.3292 - val_Verstellweg_Phi_mae: 0.0675 - val_Verstellweg_X_mae: 0.0128 - val_Verstellweg_Y_mae: 0.0903 - val_loss: 0.3073
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.0800 - Verstellweg_X_mae: 0.0111 - Verstellweg_Y_mae: 0.0919 - loss: 0.3190 - val_Verstellweg_Phi_mae: 0.0777 - val_Verstellweg_X_mae: 0.0112 - val_Verstellweg_Y_mae: 0.0942 - val_loss: 0.3167
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.0773 - Verstellweg_X_mae: 0.0108 - Verstellweg_Y_mae: 0.0908 - loss: 0.3118 - val_Verstellweg_Phi_mae: 0.0930 - val_Verstellweg_X_mae: 0.0071 - val_Verstellweg_Y_mae: 0.0814 - val_loss: 0.3125
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.0071628833949819145
# Mean Absolute Error for Verstellweg_Y: 0.08259268995579333
# Mean Absolute Error for Verstellweg_Phi: 0.0931675101691982
# 142
# 254180
# (25418, 1, 3)
# Shape für die Features der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 10, 11)
# Shape für die Features der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 10, 11)
# Shape für die Labels der gesamten Trainingsdaten, also im Falle einer Interpolation mit allen Daten (203344, 1, 3)
# Shape für die Labels der gesamten Testdaten, also im Falle einer Interpolation mit allen Daten (25418, 1, 3)
# Epoch 1/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 34s 5ms/step - Verstellweg_Phi_mae: 1.2070 - Verstellweg_X_mae: 0.1330 - Verstellweg_Y_mae: 0.9096 - loss: 3.0255 - val_Verstellweg_Phi_mae: 0.6296 - val_Verstellweg_X_mae: 0.0357 - val_Verstellweg_Y_mae: 0.4330 - val_loss: 1.4413
# Epoch 2/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.6010 - Verstellweg_X_mae: 0.0277 - Verstellweg_Y_mae: 0.4087 - loss: 1.3530 - val_Verstellweg_Phi_mae: 0.4345 - val_Verstellweg_X_mae: 0.0398 - val_Verstellweg_Y_mae: 0.3177 - val_loss: 1.0669
# Epoch 3/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - Verstellweg_Phi_mae: 0.4178 - Verstellweg_X_mae: 0.0224 - Verstellweg_Y_mae: 0.2988 - loss: 1.0088 - val_Verstellweg_Phi_mae: 0.3324 - val_Verstellweg_X_mae: 0.0183 - val_Verstellweg_Y_mae: 0.2579 - val_loss: 0.8573
# Epoch 4/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.3246 - Verstellweg_X_mae: 0.0189 - Verstellweg_Y_mae: 0.2551 - loss: 0.8430 - val_Verstellweg_Phi_mae: 0.2730 - val_Verstellweg_X_mae: 0.0090 - val_Verstellweg_Y_mae: 0.2399 - val_loss: 0.7561
# Epoch 5/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 31s 5ms/step - Verstellweg_Phi_mae: 0.2731 - Verstellweg_X_mae: 0.0140 - Verstellweg_Y_mae: 0.2248 - loss: 0.7426 - val_Verstellweg_Phi_mae: 0.2473 - val_Verstellweg_X_mae: 0.0088 - val_Verstellweg_Y_mae: 0.1923 - val_loss: 0.6701
# Epoch 6/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━
20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 30s 5ms/step - Verstellweg_Phi_mae: 0.1013 - Verstellweg_X_mae: 0.0105 - Verstellweg_Y_mae: 0.1139 - loss: 0.3839 - val_Verstellweg_Phi_mae: 0.1228 - val_Verstellweg_X_mae: 0.0124 - val_Verstellweg_Y_mae: 0.0947 - val_loss: 0.3851
# Epoch 16/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.0967 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.1130 - loss: 0.3739 - val_Verstellweg_Phi_mae: 0.1220 - val_Verstellweg_X_mae: 0.0075 - val_Verstellweg_Y_mae: 0.0990 - val_loss: 0.3790
# Epoch 17/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 32s 5ms/step - Verstellweg_Phi_mae: 0.0941 - Verstellweg_X_mae: 0.0107 - Verstellweg_Y_mae: 0.1077 - loss: 0.3615 - val_Verstellweg_Phi_mae: 0.1001 - val_Verstellweg_X_mae: 0.0109 - val_Verstellweg_Y_mae: 0.1016 - val_loss: 0.3575
# Epoch 18/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.0883 - Verstellweg_X_mae: 0.0109 - Verstellweg_Y_mae: 0.1061 - loss: 0.3503 - val_Verstellweg_Phi_mae: 0.0903 - val_Verstellweg_X_mae: 0.0075 - val_Verstellweg_Y_mae: 0.0931 - val_loss: 0.3332
# Epoch 19/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.0866 - Verstellweg_X_mae: 0.0106 - Verstellweg_Y_mae: 0.1026 - loss: 0.3409 - val_Verstellweg_Phi_mae: 0.0865 - val_Verstellweg_X_mae: 0.0156 - val_Verstellweg_Y_mae: 0.0756 - val_loss: 0.3162
# Epoch 20/20
# 6355/6355 ━━━━━━━━━━━━━━━━━━━━ 33s 5ms/step - Verstellweg_Phi_mae: 0.0827 - Verstellweg_X_mae: 0.0108 - Verstellweg_Y_mae: 0.0980 - loss: 0.3288 - val_Verstellweg_Phi_mae: 0.0940 - val_Verstellweg_X_mae: 0.0080 - val_Verstellweg_Y_mae: 0.0928 - val_loss: 0.3293
# 795/795 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step
# Mean Absolute Error for Verstellweg_X: 0.007841463311035203
# Mean Absolute Error for Verstellweg_Y: 0.0958376211970218
# Mean Absolute Error for Verstellweg_Phi: 0.09387608805186363
# MAE Standard Split:
#    CV       Datentyp Error         X         y       phi
# 0  77  Standardsplit   MAE  0.007841  0.095838  0.093876
#
# MAE Blech Split:
#    CV    Datentyp Error         X         y       phi
# 0   7  Blechsplit   MAE  0.046478  0.657759  0.907978
# 1  11  Blechsplit   MAE  0.128211  0.512740  1.098514
# 2  10  Blechsplit   MAE  0.118544  0.727455  1.430989
# 3  46  Blechsplit   MAE  0.003456  0.531011  0.664429
# 4  21  Blechsplit   MAE  0.131789  0.652944  0.425865
# 5  94  Blechsplit   MAE  0.030504  0.682810  1.260206
# 6  85  Blechsplit   MAE  0.011109  0.471961  0.884690
# 7  39  Blechsplit   MAE  0.005000  0.418947  1.032709
# 8  32  Blechsplit   MAE  0.067140  0.891692  0.702405
# 9  77  Blechsplit   MAE  0.012546  0.890387  0.982505

# %%
Mean_Standard = MAE_Standardsplit[['X','y','phi']].mean() 
Mean_Blech = MAE_BlechSplit_leer[['X','y','phi']].mean() 
Std_Standard = MAE_Standardsplit[['X','y','phi']].std()
Std_Blech = MAE_BlechSplit_leer[['X','y','phi']].std()

MAE_StandardSplit_df = pd.concat([MAE_Standardsplit, pd.DataFrame([{'CV': 'Mittelwert', 'Datentyp': 'Standardsplit', 'Error' : 'MAE', 'X': Mean_Standard[0], 'y': Mean_Standard[1], 'phi': Mean_Standard[2]}])], ignore_index=True)
MAE_BlechSplit_df = pd.concat([MAE_BlechSplit_leer, pd.DataFrame([{'CV': 'Mittelwert', 'Datentyp': 'Blechsplit', 'Error' : 'MAE', 'X': Mean_Blech[0], 'y': Mean_Blech[1], 'phi': Mean_Blech[2]}])], ignore_index=True)
MAE_StandardSplit_comp = pd.concat([MAE_StandardSplit_df, pd.DataFrame([{'CV': 'Standardabweichung', 'Datentyp': 'Standardsplit', 'Error' : 'MAE', 'X': Std_Standard[0], 'y': Std_Standard[1], 'phi': Std_Standard[2]}])], ignore_index=True)
MAE_BlechSplit_comp = pd.concat([MAE_BlechSplit_df, pd.DataFrame([{'CV': 'Standardabweichung', 'Datentyp': 'Blechsplit', 'Error' : 'MAE', 'X': Std_Blech[0], 'y': Std_Blech[1], 'phi': Std_Blech[2]}])], ignore_index=True)

# print(MAE_BlechSplit)
# print(MAE_StandardSplit)

Errors_for_CSV = pd.concat([MAE_StandardSplit_comp, MAE_BlechSplit_comp], axis=1)
print(Errors_for_CSV['X'])

Errors_for_CSV.columns = ['CV', 'Datentyp', 'Error', 'X', 'y', 'phi', 'CV1',
       'Datentyp1', 'Error1', 'X1', 'y1', 'phi1']

for Column in Errors_for_CSV.columns:
        Errors_for_CSV[Column] = Errors_for_CSV[Column].astype(str).str.replace('.', ',')
        
# for Column in Fehler_Blechsplit_df:
#         Fehler_Blechsplit_df[Column] = Fehler_Blechsplit_df[Column].astype(str).str.replace('.', ',')

for Column in Fehler_Standardsplit_df:
        Fehler_Standardsplit_df[Column] = Fehler_Standardsplit_df[Column].astype(str).str.replace('.', ',')

Ordner = r'C:\Users\corvi\OneDrive - stud.tu-darmstadt.de\Desktop\Masterthesis\13_ExcelvonDaten_Code\DeepLearning\RNN'

Fehler_Standardsplit_df.to_csv(f'{Ordner}\Fehler_RNN_Standardsplit_RandomSeed2.csv', index=True, sep=';')

Errors_for_CSV.to_csv(f'{Ordner}\Ergebnisse_RNN_Standardsplit_RandomSeed2.csv', index=True, sep=';')
# Out:
#            X    X
# 0   0.008454  NaN
# 1   0.012530  NaN
# 2   0.007647  NaN
# 3   0.009243  NaN
# 4   0.015055  NaN
# 5   0.009329  NaN
# 6   0.012981  NaN
# 7   0.007042  NaN
# 8   0.007163  NaN
# 9   0.007841  NaN
# 10  0.009729  NaN
# 11  0.002799  NaN
# C:\Users\corvi\AppData\Local\Temp\ipykernel_36652\284587766.py:21: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Errors_for_CSV[Column] = Errors_for_CSV[Column].astype(str).str.replace('.', ',')
# C:\Users\corvi\AppData\Local\Temp\ipykernel_36652\284587766.py:27: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   Fehler_Standardsplit_df[Column] = Fehler_Standardsplit_df[Column].astype(str).str.replace('.', ',')
